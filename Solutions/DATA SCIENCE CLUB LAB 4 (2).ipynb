# %%
import pandas as pd

# %%
df = pd.read_csv("PhonesPriceInKenya.csv")

# %%
df
# Out:
#                       Phone Title  \
# 0                 Gionee M7 Power
# 1                       Gionee M7
# 2     Samsung Galaxy M21 6GB128GB
# 3      Samsung Galaxy M21 4GB64GB
# 4     Samsung Galaxy A31 6GB128GB
# ...                           ...
# 1143               Nokia 105 2019
# 1144                 Nokia 220 4G
# 1145                    Nokia X71
# 1146             Nokia 22 3GB32GB
# 1147             Nokia 22 2GB16GB
#
#                                                   Specs Price(Kshs)  Rating  \
# 0     Screen:6.0 inches, 720 x 1440 pixels,Front Cam...      11,800     4.0
# 1     Screen:6.01 inches, 1080 x 2160 pixels,Front C...       7,999     4.5
# 2     Screen:6.4 inches, 1080 x 2340 pixels,Front Ca...      22,590     4.3
# 3     Screen:6.4 inches, 1080 x 2340 pixels,Front Ca...      22,499     3.8
# 4     Screen:6.4 inches, 1080 x 2400 pixels,Front Ca...      24,999     3.8
# ...                                                 ...         ...     ...
# ...

# %%
#checking for null values
df.isna().sum()
# Out:
# Phone Title     0
# Specs           0
# Price(Kshs)    78
# Rating          0
# Specs Score     0
# Likes           0
# dtype: int64

# %%
#droping null values in the Price(Kshs) column
df = df.dropna(subset=['Price(Kshs)'])
df.isna().sum()
# Out:
# Phone Title    0
# Specs          0
# Price(Kshs)    0
# Rating         0
# Specs Score    0
# Likes          0
# dtype: int64

# %%
#creating columns
#screen inches
df['screen_inches']= df['Specs'].str.split(' ').str[0]
df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4968\3179721492.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['screen_inches']= df['Specs'].str.split(' ').str[0]
#                       Phone Title  \
# 0                 Gionee M7 Power
# 1                       Gionee M7
# 2     Samsung Galaxy M21 6GB128GB
# 3      Samsung Galaxy M21 4GB64GB
# 4     Samsung Galaxy A31 6GB128GB
# ...                           ...
# 1138            Nokia 72 6GB128GB
# 1139             Nokia 72 4GB64GB
# 1141             Nokia 62 4GB64GB
# 1143               Nokia 105 2019
# 1147             Nokia 22 2GB16GB
#
#                                                   Specs Price(Kshs)  Rating  \
# ...

# %%
df['screen_inches1']= df['screen_inches'].str.split(':').str[1]
df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4968\3801320309.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['screen_inches1']= df['screen_inches'].str.split(':').str[1]
#                       Phone Title  \
# 0                 Gionee M7 Power
# 1                       Gionee M7
# 2     Samsung Galaxy M21 6GB128GB
# 3      Samsung Galaxy M21 4GB64GB
# 4     Samsung Galaxy A31 6GB128GB
# ...                           ...
# 1138            Nokia 72 6GB128GB
# 1139             Nokia 72 4GB64GB
# 1141             Nokia 62 4GB64GB
# 1143               Nokia 105 2019
# 1147             Nokia 22 2GB16GB
#
#                                                   Specs Price(Kshs)  Rating  \
# ...

# %%
#creating a pixels column
df['pixels']= df['Specs'].str.split(' ').str[2:5]
df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4968\2671952828.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pixels']= df['Specs'].str.split(' ').str[2:5]
#                       Phone Title  \
# 0                 Gionee M7 Power
# 1                       Gionee M7
# 2     Samsung Galaxy M21 6GB128GB
# 3      Samsung Galaxy M21 4GB64GB
# 4     Samsung Galaxy A31 6GB128GB
# ...                           ...
# 1138            Nokia 72 6GB128GB
# 1139             Nokia 72 4GB64GB
# 1141             Nokia 62 4GB64GB
# 1143               Nokia 105 2019
# 1147             Nokia 22 2GB16GB
#
#                                                   Specs Price(Kshs)  Rating  \
# ...

# %%
#creating a column . phone model
df['phone_model']= df['Phone Title'].str.split(' ').str[0:2]
df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4968\1995923987.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['phone_model']= df['Phone Title'].str.split(' ').str[0:2]
#                       Phone Title  \
# 0                 Gionee M7 Power
# 1                       Gionee M7
# 2     Samsung Galaxy M21 6GB128GB
# 3      Samsung Galaxy M21 4GB64GB
# 4     Samsung Galaxy A31 6GB128GB
# ...                           ...
# 1138            Nokia 72 6GB128GB
# 1139             Nokia 72 4GB64GB
# 1141             Nokia 62 4GB64GB
# 1143               Nokia 105 2019
# 1147             Nokia 22 2GB16GB
#
#                                                   Specs Price(Kshs)  Rating  \
# ...

# %%
#Find the top 10 most expensive Samsung phones
#creating a column for samsung phones only
df['Samsung_Phones'] = df['Phone Title'].apply(lambda x: x if 'Samsung' in x else None )
df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4968\1379073371.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Samsung_Phones'] = df['Phone Title'].apply(lambda x: x if 'Samsung' in x else None )
#                       Phone Title  \
# 0                 Gionee M7 Power
# 1                       Gionee M7
# 2     Samsung Galaxy M21 6GB128GB
# 3      Samsung Galaxy M21 4GB64GB
# 4     Samsung Galaxy A31 6GB128GB
# ...                           ...
# 1138            Nokia 72 6GB128GB
# 1139             Nokia 72 4GB64GB
# 1141             Nokia 62 4GB64GB
# 1143               Nokia 105 2019
# 1147             Nokia 22 2GB16GB
#
#                                                   Specs Price(Kshs)  Rating  \
# ...

# %%
#creating a dataframe for samsung phones only
prices_columns=['Samsung_Phones','Price(Kshs)']
prices_columns_df = df[prices_columns]
prices_columns_df
# Out:
#                    Samsung_Phones Price(Kshs)
# 0                            None      11,800
# 1                            None       7,999
# 2     Samsung Galaxy M21 6GB128GB      22,590
# 3      Samsung Galaxy M21 4GB64GB      22,499
# 4     Samsung Galaxy A31 6GB128GB      24,999
# ...                           ...         ...
# 1138                         None      29,999
# 1139                         None      26,000
# 1141                         None      20,500
# 1143                         None       1,900
# 1147                         None       9,500
#
# [1070 rows x 2 columns]

# %%
#remoing null values from the prices_columns_df dataframe
prices_columns_df= prices_columns_df.dropna()
prices_columns_df
# Out:
#                     Samsung_Phones Price(Kshs)
# 2      Samsung Galaxy M21 6GB128GB      22,590
# 3       Samsung Galaxy M21 4GB64GB      22,499
# 4      Samsung Galaxy A31 6GB128GB      24,999
# 5       Samsung Galaxy A31 4GB64GB      24,499
# 6       Samsung Galaxy A11 3GB32GB      13,999
# ..                             ...         ...
# 923    Samsung Galaxy Note 5 32 GB      11,000
# 924   Samsung Galaxy Note 8 256 GB      10,599
# 925   Samsung Galaxy Note 8 128 GB       1,150
# 926    Samsung Galaxy Note 8 64 GB       1,150
# 927  Samsung Galaxy S8 Plus 128 GB         769
#
# [180 rows x 2 columns]

# %%
# Get the 10 most expensive phones in the dataframe prices_columns_df
# Remove commas from the 'Price(Kshs)' column and convert to float

# Ensure all values in 'Price(Kshs)' column are strings before using .str accessor
prices_columns_df['Price(Kshs)'] = prices_columns_df['Price(Kshs)'].astype(str)
prices_columns_df['Price(Kshs)'] = prices_columns_df['Price(Kshs)'].str.replace(',', '').astype(float)

# Find the 10 most expensive phones
top_10_expensive_phones = prices_columns_df.nlargest(10, 'Price(Kshs)')
top_10_expensive_phones
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4968\4163490325.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prices_columns_df['Price(Kshs)'] = prices_columns_df['Price(Kshs)'].astype(str)
# C:\Users\hp\AppData\Local\Temp\ipykernel_4968\4163490325.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prices_columns_df['Price(Kshs)'] = prices_columns_df['Price(Kshs)'].str.replace(',', '').astype(float)
#                                     Samsung_Phones  Price(Kshs)
# ...

# %%
#Find the top 10 most cheapest apple phones
#creating a column for apple phones only
df['Apple iPhone'] = df['Phone Title'].apply(lambda x: x if 'Apple iPhone' in x else None )
df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4968\2124776492.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Apple iPhone'] = df['Phone Title'].apply(lambda x: x if 'Apple iPhone' in x else None )
#                       Phone Title  \
# 0                 Gionee M7 Power
# 1                       Gionee M7
# 2     Samsung Galaxy M21 6GB128GB
# 3      Samsung Galaxy M21 4GB64GB
# 4     Samsung Galaxy A31 6GB128GB
# ...                           ...
# 1138            Nokia 72 6GB128GB
# 1139             Nokia 72 4GB64GB
# 1141             Nokia 62 4GB64GB
# 1143               Nokia 105 2019
# 1147             Nokia 22 2GB16GB
#
#                                                   Specs Price(Kshs)  Rating  \
# ...

# %%
# Creating a dataframe for apple phones only
prices_columns_apple = ['Apple iPhone', 'Price(Kshs)']
prices_columns_apple_df = df[prices_columns_apple]
prices_columns_apple_df
# Out:
#      Apple iPhone Price(Kshs)
# 0            None      11,800
# 1            None       7,999
# 2            None      22,590
# 3            None      22,499
# 4            None      24,999
# ...           ...         ...
# 1138         None      29,999
# 1139         None      26,000
# 1141         None      20,500
# 1143         None       1,900
# 1147         None       9,500
#
# [1070 rows x 2 columns]

# %%
# Ensure all values in 'Price(Kshs)' column are strings before using .str accessor
prices_columns_apple_df['Price(Kshs)'] = prices_columns_apple_df['Price(Kshs)'].astype(str)
prices_columns_apple_df['Price(Kshs)'] = prices_columns_apple_df['Price(Kshs)'].str.replace(',', '').astype(float)

# Removing null values from the prices_columns_apple_df dataframe

prices_columns_apple_df = prices_columns_apple_df.dropna()
prices_columns_apple_df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4968\706726898.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prices_columns_apple_df['Price(Kshs)'] = prices_columns_apple_df['Price(Kshs)'].astype(str)
# C:\Users\hp\AppData\Local\Temp\ipykernel_4968\706726898.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prices_columns_apple_df['Price(Kshs)'] = prices_columns_apple_df['Price(Kshs)'].str.replace(',', '').astype(float)
#                        Apple iPhone  Price(Kshs)
# ...

# %%
# finding the cheapest iphones
cheapest_iphones = prices_columns_apple_df.nsmallest(10, 'Price(Kshs)')
cheapest_iphones
# Out:
#                     Apple iPhone  Price(Kshs)
# 261     Apple iPhone 6 Plus 64GB       5150.0
# 260         Apple iPhone 5s 16GB      12199.0
# 1070       Apple iPhone 6s 16 GB      23000.0
# 1068       Apple iPhone 6s 64 GB      23500.0
# 1067      Apple iPhone 6s 128 GB      23999.0
# 1069       Apple iPhone 6s 32 GB      25000.0
# 1076        Apple iPhone 7 32 GB      29500.0
# 1064  Apple iPhone 6s Plus 64 GB      30500.0
# 1065  Apple iPhone 6s Plus 32 GB      32000.0
# 1075       Apple iPhone 7 128 GB      32000.0

# %%
#How many Samsung Galaxy A series are in the dataset?
#creating a column for galaxy A series phones

df['Samsung Galaxy A'] = df['Phone Title'].apply(lambda x: x if 'Samsung Galaxy A' in x else None )
df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4968\850177571.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Samsung Galaxy A'] = df['Phone Title'].apply(lambda x: x if 'Samsung Galaxy A' in x else None )
#                       Phone Title  \
# 0                 Gionee M7 Power
# 1                       Gionee M7
# 2     Samsung Galaxy M21 6GB128GB
# 3      Samsung Galaxy M21 4GB64GB
# 4     Samsung Galaxy A31 6GB128GB
# ...                           ...
# 1138            Nokia 72 6GB128GB
# 1139             Nokia 72 4GB64GB
# 1141             Nokia 62 4GB64GB
# 1143               Nokia 105 2019
# 1147             Nokia 22 2GB16GB
#
#                                                   Specs Price(Kshs)  Rating  \
# ...

# %%
# Creating a dataframe for Samsung Galaxy A only
Samsung_Galaxy_A = ['Samsung Galaxy A']
Samsung_Galaxy_A_df = df[Samsung_Galaxy_A ]
Samsung_Galaxy_A_df
# Out:
#                  Samsung Galaxy A
# 0                            None
# 1                            None
# 2                            None
# 3                            None
# 4     Samsung Galaxy A31 6GB128GB
# ...                           ...
# 1138                         None
# 1139                         None
# 1141                         None
# 1143                         None
# 1147                         None
#
# [1070 rows x 1 columns]

# %%
#droping null values in Samsung_Galaxy_A_df
Samsung_Galaxy_A_df = Samsung_Galaxy_A_df.dropna()
Samsung_Galaxy_A_df
# Out:
#                      Samsung Galaxy A
# 4         Samsung Galaxy A31 6GB128GB
# 5          Samsung Galaxy A31 4GB64GB
# 6          Samsung Galaxy A11 3GB32GB
# 7          Samsung Galaxy A11 2GB32GB
# 19        Samsung Galaxy A51 4GB128GB
# ..                                ...
# 625      Samsung Galaxy A7 2018 128GB
# 627           Samsung Galaxy A6s 64GB
# 635       Samsung Galaxy A7 2018 64GB
# 636       Samsung Galaxy A6 2018 64GB
# 637  Samsung Galaxy A6 Plus 2018 64GB
#
# [64 rows x 1 columns]

# %%
# Counting the number of phones in the Samsung_Galaxy_A_df dataframe
num_phones_samsung_galaxy_a = Samsung_Galaxy_A_df.shape[0]
num_phones_samsung_galaxy_a
# Out:
# 64

# %%
#finding the most popular phone brand
# Extracting the phone brand from the 'Phone Title' column
df['Brand'] = df['Phone Title'].apply(lambda x: x.split()[0])

# Counting the number of occurrences of each brand
brand_counts = df['Brand'].value_counts()

# Getting the most popular phone brand
most_popular_brand = brand_counts.idxmax()
most_popular_brand
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4968\4256231467.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Brand'] = df['Phone Title'].apply(lambda x: x.split()[0])
# 'Samsung'

# %%
#Does likes affect the ratings of a phone model?
# Importing necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Checking the relationship between 'Likes' and 'Rating'
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Likes', y='Rating')
plt.title('Relationship between Likes and Rating')
plt.xlabel('Likes')
plt.ylabel('Rating')
plt.show()

# Calculating the correlation coefficient between 'Likes' and 'Rating'
correlation_likes_rating = df['Likes'].corr(df['Rating'])
correlation_likes_rating
# Out:
# -0.17108244555481442

# %%
# Does ratings affect the price of a phone model?
# Checking the relationship between 'Rating' and 'Price(Kshs)'
sample_df = df.sample(n=30, random_state=1)

plt.figure(figsize=(10, 6))
sns.scatterplot(data=sample_df, x='Rating', y='Price(Kshs)')
plt.title('Relationship between Rating and Price')
plt.xlabel('Rating')
plt.ylabel('Price (Kshs)')
plt.show()



# Remove commas from the 'Price(Kshs)' column and convert to float
# Ensure all values in 'Price(Kshs)' column are strings before using .str accessor
df['Price(Kshs)'] = df['Price(Kshs)'].astype(str)
df['Price(Kshs)'] = df['Price(Kshs)'].str.replace(',', '').astype(float)


# Calculating the correlation coefficient between 'Rating' and 'Price(Kshs)'
correlation_rating_price = df['Rating'].corr(df['Price(Kshs)'])
correlation_rating_price
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4968\2247867362.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price(Kshs)'] = df['Price(Kshs)'].astype(str)
# C:\Users\hp\AppData\Local\Temp\ipykernel_4968\2247867362.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price(Kshs)'] = df['Price(Kshs)'].str.replace(',', '').astype(float)
# 0.05189459607984672
